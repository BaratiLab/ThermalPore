# %% [markdown]
# # IoU

# %%
import os
import numpy as np
import pickle
import matplotlib.pyplot as plt
import matplotlib.animation as animation
import matplotlib.patches as mpatches
import torch

from torchmetrics import JaccardIndex
from matplotlib.colors import ListedColormap
from tqdm import tqdm

# %%
# Load Split Indexes
train_indexes = np.load("./train_indexes.npy")
test_indexes = np.load("./test_indexes.npy")

print(f"train_indexes ({len(train_indexes)}): {train_indexes}")
print(f"test_indexes ({len(test_indexes)}): {test_indexes}")
# Out:
# train_indexes (240): [ 50 102 134 284  25 252 144 151 242 307 314 198 154 156 177 142 277 231
#  207 170  60  79 303 108 173  11 165 220  26 300  56 201 129 114  21 248
#  183 163 155 136 159 306 210 313 227 203 181 226 244  54 193 239 276 219
#   86  92 130 294 115 139   6 229 111  18 302 272 194  40 288 119  97  43
#  271 281  15  51 234 150 103  87  57   9 153 285  59 208 254 310   7 172
#  120 240 215 317  46  36 152  76 141 237 273  75  38 184  70 143 223 269
#   24  71 291  81 316 216 305  89 233   2 132  10 283  96 218 297 164 188
#   14 225 182  49 189 169 251 309 301 308 171 105  72 257  64  67  90 250
#  304  78 241 200  33 311 298 299 256  69 107  39 287  13 191 258   1   4
#  179  82 185 279 162  31  91  27 278  28 228  41  45 262  93 268 167 101
#   65  30 270  98 202 217 124 161 280 290 249 180  66 247 158  37 116 212
#  140  16  95 168 253 135  42 109 121 260 197 224 123  61 236 106  63 125
#   20 264 266 205 222 199 261  53 209 118 127 149  88 157  62 186 131  84
#    8 122 295  19 204  44]
# test_indexes (78): [221 147 214 312  99 117  68 128 286 267 175  12  35 104 160 178 246 195
#  112  83 100 238 255 245  23  58 138   5 211   0 113 145  73 190 263  22
#  265  17 230  47  32   3 174  77 148 315 213  48  55  94 206 110  34 282
#  137  80 274 126  52 293 196 292 243 166 146 275 296  85 259 133  74 289
#   29 187 192 235 232 176]

# %%
EPOCH = 1000

# %%
jaccard = JaccardIndex(task="multiclass", num_classes=2)
jaccard_ignore = JaccardIndex(task="multiclass", num_classes=2, ignore_index=0)

if not os.path.isdir("iou"):
    os.mkdir("iou")

# epochs_iou = []
# epochs_iou_ignore = []
# epochs_predictions = []

with open(f"./targets.p", "rb") as targets_file:
    targets = pickle.load(targets_file)

test_length = len(test_indexes)

if not os.path.isdir(f"iou/{EPOCH}"):
    os.mkdir(f"iou/{EPOCH}")

build_layers_iou = []
build_layers_iou_ignore = []
for index in range(test_length):
    predictions = []

    with open(f"./predictions/{EPOCH}.p", "rb") as predictions_file:
        predictions = pickle.load(predictions_file)

    prediction = predictions[index].squeeze()
    # prediction = np.transpose(prediction, (1, 0, 2))

    target = targets[index].squeeze()
    # target = np.transpose(target, (1, 0, 2))

    # print(prediction.shape)

    build_layer_iou = jaccard(torch.tensor(prediction), torch.tensor(target))
    build_layers_iou.append(build_layer_iou)

    # Sets correct prediction of no pores to 1.
    prediction_not_empty = np.any(np.array(prediction) == 1)
    target_not_empty = np.any(np.array(target) == 1)
    if (prediction_not_empty, target_not_empty):
        build_layer_iou_ignore = torch.tensor(1.0)
        build_layer_iou = torch.tensor(1.0)

    build_layer_iou_ignore = jaccard_ignore(torch.tensor(prediction), torch.tensor(target))
    build_layers_iou_ignore.append(build_layer_iou_ignore)

iou = np.array([value for _, value in sorted(zip(test_indexes, build_layers_iou))])
# epochs_iou.append(epoch_iou)

iou_ignore = np.array([value for _, value in sorted(zip(test_indexes, build_layers_iou_ignore))])
# epochs_iou_ignore.append(epoch_iou_ignore)

# epochs_predictions.append(predictions)
# Out:
# /tmp/ipykernel_3305416/876133483.py:35: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   build_layer_iou = jaccard(torch.tensor(prediction), torch.tensor(target))
# /tmp/ipykernel_3305416/876133483.py:45: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   build_layer_iou_ignore = jaccard_ignore(torch.tensor(prediction), torch.tensor(target))

# %%
# sorted_test_indexes = sorted(test_indexes)
# print(sorted_test_indexes)

dataset_index = np.array([divmod(layer_index, 159)[0] for layer_index in test_indexes])
build_layer_index = np.array([divmod(layer_index, 159)[1] for layer_index in test_indexes])

spacing_mask = dataset_index == 0
velocity_mask = dataset_index == 1

# print(len(iou_ignore), iou_ignore)
# print(len(dataset_index), dataset_index)
# print(len(build_layer_index), build_layer_index)
# print(spacing_mask)
# print(velocity_mask)

# %%
spacing_build_layers = build_layer_index[spacing_mask]
spacing_sorted = np.argsort(spacing_build_layers)
spacing_sorted_build_layers = spacing_build_layers[spacing_sorted]

spacing_iou = iou_ignore[spacing_mask]
# spacing_sorted_iou = spacing_iou[spacing_sorted]

velocity_build_layers = build_layer_index[velocity_mask]
velocity_sorted = np.argsort(velocity_build_layers)
velocity_sorted_build_layers = velocity_build_layers[velocity_sorted]

# print(velocity_build_layers)
# print(velocity_sorted_build_layers)

velocity_iou = iou_ignore[velocity_mask]
# velocity_sorted_iou = velocity_iou[velocity_sorted]

# print(velocity_iou)
# print(velocity_sorted_iou)

min, mean, max = np.min(iou_ignore), np.mean(iou_ignore), np.max(iou_ignore)
print(f"Epoch {EPOCH} -> min: {min}, mean: {mean}, max: {max}")
# Out:
# Epoch 1000 -> min: nan, mean: nan, max: nan

# %%
plt.figure(figsize=(6, 6))
plt.bar(
    spacing_sorted_build_layers,
    spacing_iou,
    color="red",
    width=5,
    alpha=0.5,
    label="Spacing",
)
plt.bar(
    velocity_sorted_build_layers,
    velocity_iou,
    color="blue",
    width=5,
    alpha=0.5,
    label="Velocity"
)

# Increase border thickness
plt.gca().spines['top'].set_linewidth(2)
plt.gca().spines['right'].set_linewidth(2)
plt.gca().spines['bottom'].set_linewidth(2)
plt.gca().spines['left'].set_linewidth(2)

# Add labels and title
plt.xlabel('Build Layer', fontsize=18)
plt.ylabel('IoU', fontsize=18)
plt.tick_params(direction="in", labelsize=14, width=2)

plt.legend()
plt.savefig(f"iou/{EPOCH}/ignore_background.png")
plt.show()

# %%
for index in tqdm(range(test_length)):
    prediction = predictions[index]

    target = targets[index]

    fig, axes = plt.subplots(2, 2, figsize=(8,7))

    cmap = plt.get_cmap('viridis')
    cmap_zero_transparent = ListedColormap(cmap(np.arange(cmap.N)))
    cmap_zero_transparent.set_bad(alpha=0)

    plt.subplots_adjust(top=0.85)

    def animate(frame_index):
        prediction_voxel = torch.tensor(prediction.squeeze())
        target_voxel = torch.tensor(target.squeeze())

        # iou_build_layer = epochs_iou[epoch_index][index]
        # iou_build_layer_ignore = epochs_iou_ignore[epoch_index][index]
        iou = jaccard(prediction_voxel, target_voxel)
        iou_ignore = jaccard_ignore(prediction_voxel, target_voxel)

        fig.suptitle(f"Index: {index}, Build Layer: {build_layer_index[index]}, IOU: {iou:.3f} IOU (ignore bg): {iou_ignore:.3f}", fontsize=18)

        axes[0][0].clear()
        axes[0][0].set_title("Prediction", fontsize=12)
        axes[0][0].imshow(prediction[frame_index], vmin=0, vmax=2)

        axes[0][1].clear()
        axes[0][1].set_title("Ground Truth", fontsize=12)
        axes[0][1].imshow(target[frame_index], vmin=0, vmax=3)

        axes[1][0].clear()
        axes[1][0].set_title("Intersection", fontsize=12)

        scaled_prediction = prediction[frame_index] * 2
        values = target[frame_index] + scaled_prediction
        values_nan = np.where(values == 0, np.nan, values)

        img_2 = axes[1][0].imshow(values_nan, vmin=0, vmax=3, cmap=cmap_zero_transparent)

        # Add legend for values 1 and 2
        legend_elements = [
            mpatches.Patch(color=img_2.cmap(0.33), label='Ground Truth'),
            mpatches.Patch(color=img_2.cmap(0.66), label='Prediction'),
            mpatches.Patch(color=img_2.cmap(1.0), label='Intersection'),
        ]
        axes[1][0].legend(handles=legend_elements, loc="upper right")

        error = target[frame_index] - prediction[frame_index] + 1
        error_nan = np.where(error == 1, np.nan, error)

        axes[1][1].clear()
        axes[1][1].set_title("Error", fontsize=12)

        img_3 = axes[1][1].imshow(error_nan, vmin=0, vmax=2, cmap=cmap_zero_transparent)

        # Add legend for values 1 and 2
        legend_elements = [
            mpatches.Patch(color=img_3.cmap(0.0), label='Ground Truth'),
            mpatches.Patch(color=img_3.cmap(1.0), label='Prediction'),
        ]

        axes[1][1].legend(handles=legend_elements, loc="upper right")

    anim = animation.FuncAnimation(fig, animate, frames=len(prediction), interval=1000)
    anim.save(f"iou/{EPOCH}/build_layer_{build_layer_index[index]}_dataset_{dataset_index[index]}_layer__2x2.gif", writer="imagemagick")

    plt.close()
# Out:
#   0%|          | 0/78 [00:00<?, ?it/s]MovieWriter imagemagick unavailable; using Pillow instead.
# /tmp/ipykernel_3305416/548090082.py:16: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   target_voxel = torch.tensor(target.squeeze())
#   1%|▏         | 1/78 [00:00<00:36,  2.12it/s]MovieWriter imagemagick unavailable; using Pillow instead.
# /tmp/ipykernel_3305416/548090082.py:16: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   target_voxel = torch.tensor(target.squeeze())
#   3%|▎         | 2/78 [00:01<00:41,  1.84it/s]MovieWriter imagemagick unavailable; using Pillow instead.
# /tmp/ipykernel_3305416/548090082.py:16: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   target_voxel = torch.tensor(target.squeeze())
#   4%|▍         | 3/78 [00:01<00:37,  1.98it/s]MovieWriter imagemagick unavailable; using Pillow instead.
# /tmp/ipykernel_3305416/548090082.py:16: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   target_voxel = torch.tensor(target.squeeze())
#   5%|▌         | 4/78 [00:02<00:37,  2.00it/s]MovieWriter imagemagick unavailable; using Pillow instead.
# /tmp/ipykernel_3305416/548090082.py:16: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   target_voxel = torch.tensor(target.squeeze())
#   6%|▋         | 5/78 [00:02<00:38,  1.88it/s]MovieWriter imagemagick unavailable; using Pillow instead.
# /tmp/ipykernel_3305416/548090082.py:16: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   target_voxel = torch.tensor(target.squeeze())
#   8%|▊         | 6/78 [00:03<00:36,  1.96it/s]MovieWriter imagemagick unavailable; using Pillow instead.
# /tmp/ipykernel_3305416/548090082.py:16: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   target_voxel = torch.tensor(target.squeeze())
#   9%|▉         | 7/78 [00:03<00:35,  2.03it/s]MovieWriter imagemagick unavailable; using Pillow instead.
# /tmp/ipykernel_3305416/548090082.py:16: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   target_voxel = torch.tensor(target.squeeze())
#  10%|█         | 8/78 [00:04<00:35,  1.99it/s]MovieWriter imagemagick unavailable; using Pillow instead.
# /tmp/ipykernel_3305416/548090082.py:16: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   target_voxel = torch.tensor(target.squeeze())
#  12%|█▏        | 9/78 [00:04<00:37,  1.86it/s]MovieWriter imagemagick unavailable; using Pillow instead.
# /tmp/ipykernel_3305416/548090082.py:16: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   target_voxel = torch.tensor(target.squeeze())
#  13%|█▎        | 10/78 [00:05<00:35,  1.91it/s]MovieWriter imagemagick unavailable; using Pillow instead.
# /tmp/ipykernel_3305416/548090082.py:16: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   target_voxel = torch.tensor(target.squeeze())
#  14%|█▍        | 11/78 [00:05<00:34,  1.95it/s]MovieWriter imagemagick unavailable; using Pillow instead.
# /tmp/ipykernel_3305416/548090082.py:16: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   target_voxel = torch.tensor(target.squeeze())
#  15%|█▌        | 12/78 [00:06<00:32,  2.00it/s]MovieWriter imagemagick unavailable; using Pillow instead.
# /tmp/ipykernel_3305416/548090082.py:16: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   target_voxel = torch.tensor(target.squeeze())
#  17%|█▋        | 13/78 [00:06<00:35,  1.82it/s]MovieWriter imagemagick unavailable; using Pillow instead.
# /tmp/ipykernel_3305416/548090082.py:16: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   target_voxel = torch.tensor(target.squeeze())
#  18%|█▊        | 14/78 [00:07<00:34,  1.87it/s]MovieWriter imagemagick unavailable; using Pillow instead.
# /tmp/ipykernel_3305416/548090082.py:16: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   target_voxel = torch.tensor(target.squeeze())
#  19%|█▉        | 15/78 [00:07<00:32,  1.96it/s]MovieWriter imagemagick unavailable; using Pillow instead.
# /tmp/ipykernel_3305416/548090082.py:16: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   target_voxel = torch.tensor(target.squeeze())
#  21%|██        | 16/78 [00:08<00:30,  2.02it/s]MovieWriter imagemagick unavailable; using Pillow instead.
# /tmp/ipykernel_3305416/548090082.py:16: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   target_voxel = torch.tensor(target.squeeze())
#  22%|██▏       | 17/78 [00:08<00:30,  2.03it/s]MovieWriter imagemagick unavailable; using Pillow instead.
# /tmp/ipykernel_3305416/548090082.py:16: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   target_voxel = torch.tensor(target.squeeze())
#  23%|██▎       | 18/78 [00:09<00:29,  2.06it/s]MovieWriter imagemagick unavailable; using Pillow instead.
# /tmp/ipykernel_3305416/548090082.py:16: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   target_voxel = torch.tensor(target.squeeze())
#  24%|██▍       | 19/78 [00:09<00:31,  1.85it/s]MovieWriter imagemagick unavailable; using Pillow instead.
# /tmp/ipykernel_3305416/548090082.py:16: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   target_voxel = torch.tensor(target.squeeze())
#  26%|██▌       | 20/78 [00:10<00:30,  1.90it/s]MovieWriter imagemagick unavailable; using Pillow instead.
# /tmp/ipykernel_3305416/548090082.py:16: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   target_voxel = torch.tensor(target.squeeze())
#  27%|██▋       | 21/78 [00:10<00:28,  1.98it/s]MovieWriter imagemagick unavailable; using Pillow instead.
# /tmp/ipykernel_3305416/548090082.py:16: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   target_voxel = torch.tensor(target.squeeze())
#  28%|██▊       | 22/78 [00:11<00:27,  2.05it/s]MovieWriter imagemagick unavailable; using Pillow instead.
# /tmp/ipykernel_3305416/548090082.py:16: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   target_voxel = torch.tensor(target.squeeze())
#  29%|██▉       | 23/78 [00:11<00:26,  2.09it/s]MovieWriter imagemagick unavailable; using Pillow instead.
# /tmp/ipykernel_3305416/548090082.py:16: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   target_voxel = torch.tensor(target.squeeze())
#  31%|███       | 24/78 [00:12<00:29,  1.81it/s]MovieWriter imagemagick unavailable; using Pillow instead.
# /tmp/ipykernel_3305416/548090082.py:16: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   target_voxel = torch.tensor(target.squeeze())
#  32%|███▏      | 25/78 [00:12<00:27,  1.90it/s]MovieWriter imagemagick unavailable; using Pillow instead.
# /tmp/ipykernel_3305416/548090082.py:16: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   target_voxel = torch.tensor(target.squeeze())
#  33%|███▎      | 26/78 [00:13<00:27,  1.92it/s]MovieWriter imagemagick unavailable; using Pillow instead.
# /tmp/ipykernel_3305416/548090082.py:16: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   target_voxel = torch.tensor(target.squeeze())
#  35%|███▍      | 27/78 [00:13<00:25,  1.98it/s]MovieWriter imagemagick unavailable; using Pillow instead.
# /tmp/ipykernel_3305416/548090082.py:16: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   target_voxel = torch.tensor(target.squeeze())
#  36%|███▌      | 28/78 [00:14<00:25,  1.97it/s]MovieWriter imagemagick unavailable; using Pillow instead.
# /tmp/ipykernel_3305416/548090082.py:16: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   target_voxel = torch.tensor(target.squeeze())
#  37%|███▋      | 29/78 [00:14<00:24,  1.97it/s]MovieWriter imagemagick unavailable; using Pillow instead.
# /tmp/ipykernel_3305416/548090082.py:16: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   target_voxel = torch.tensor(target.squeeze())
#  38%|███▊      | 30/78 [00:15<00:24,  1.97it/s]MovieWriter imagemagick unavailable; using Pillow instead.
# /tmp/ipykernel_3305416/548090082.py:16: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   target_voxel = torch.tensor(target.squeeze())
#  40%|███▉      | 31/78 [00:16<00:27,  1.72it/s]MovieWriter imagemagick unavailable; using Pillow instead.
# /tmp/ipykernel_3305416/548090082.py:16: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   target_voxel = torch.tensor(target.squeeze())
#  41%|████      | 32/78 [00:16<00:25,  1.80it/s]MovieWriter imagemagick unavailable; using Pillow instead.
# /tmp/ipykernel_3305416/548090082.py:16: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   target_voxel = torch.tensor(target.squeeze())
#  42%|████▏     | 33/78 [00:17<00:23,  1.90it/s]MovieWriter imagemagick unavailable; using Pillow instead.
# /tmp/ipykernel_3305416/548090082.py:16: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   target_voxel = torch.tensor(target.squeeze())
#  44%|████▎     | 34/78 [00:17<00:22,  1.95it/s]MovieWriter imagemagick unavailable; using Pillow instead.
# /tmp/ipykernel_3305416/548090082.py:16: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   target_voxel = torch.tensor(target.squeeze())
#  45%|████▍     | 35/78 [00:18<00:21,  2.01it/s]MovieWriter imagemagick unavailable; using Pillow instead.
# /tmp/ipykernel_3305416/548090082.py:16: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   target_voxel = torch.tensor(target.squeeze())
#  46%|████▌     | 36/78 [00:18<00:20,  2.06it/s]MovieWriter imagemagick unavailable; using Pillow instead.
# /tmp/ipykernel_3305416/548090082.py:16: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   target_voxel = torch.tensor(target.squeeze())
#  47%|████▋     | 37/78 [00:18<00:20,  2.02it/s]MovieWriter imagemagick unavailable; using Pillow instead.
# /tmp/ipykernel_3305416/548090082.py:16: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   target_voxel = torch.tensor(target.squeeze())
#  49%|████▊     | 38/78 [00:19<00:23,  1.72it/s]MovieWriter imagemagick unavailable; using Pillow instead.
# /tmp/ipykernel_3305416/548090082.py:16: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   target_voxel = torch.tensor(target.squeeze())
#  50%|█████     | 39/78 [00:20<00:21,  1.83it/s]MovieWriter imagemagick unavailable; using Pillow instead.
# /tmp/ipykernel_3305416/548090082.py:16: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   target_voxel = torch.tensor(target.squeeze())
#  51%|█████▏    | 40/78 [00:20<00:20,  1.89it/s]MovieWriter imagemagick unavailable; using Pillow instead.
# /tmp/ipykernel_3305416/548090082.py:16: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   target_voxel = torch.tensor(target.squeeze())
#  53%|█████▎    | 41/78 [00:21<00:19,  1.92it/s]MovieWriter imagemagick unavailable; using Pillow instead.
# /tmp/ipykernel_3305416/548090082.py:16: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   target_voxel = torch.tensor(target.squeeze())
#  54%|█████▍    | 42/78 [00:21<00:18,  1.91it/s]MovieWriter imagemagick unavailable; using Pillow instead.
# /tmp/ipykernel_3305416/548090082.py:16: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   target_voxel = torch.tensor(target.squeeze())
#  55%|█████▌    | 43/78 [00:22<00:18,  1.91it/s]MovieWriter imagemagick unavailable; using Pillow instead.
# /tmp/ipykernel_3305416/548090082.py:16: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   target_voxel = torch.tensor(target.squeeze())
#  56%|█████▋    | 44/78 [00:22<00:17,  1.96it/s]MovieWriter imagemagick unavailable; using Pillow instead.
# /tmp/ipykernel_3305416/548090082.py:16: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   target_voxel = torch.tensor(target.squeeze())
#  58%|█████▊    | 45/78 [00:23<00:16,  2.03it/s]MovieWriter imagemagick unavailable; using Pillow instead.
# /tmp/ipykernel_3305416/548090082.py:16: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   target_voxel = torch.tensor(target.squeeze())
#  59%|█████▉    | 46/78 [00:24<00:18,  1.69it/s]MovieWriter imagemagick unavailable; using Pillow instead.
# /tmp/ipykernel_3305416/548090082.py:16: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   target_voxel = torch.tensor(target.squeeze())
#  60%|██████    | 47/78 [00:24<00:17,  1.78it/s]MovieWriter imagemagick unavailable; using Pillow instead.
# /tmp/ipykernel_3305416/548090082.py:16: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   target_voxel = torch.tensor(target.squeeze())
#  62%|██████▏   | 48/78 [00:25<00:16,  1.82it/s]MovieWriter imagemagick unavailable; using Pillow instead.
# /tmp/ipykernel_3305416/548090082.py:16: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   target_voxel = torch.tensor(target.squeeze())
#  63%|██████▎   | 49/78 [00:25<00:15,  1.91it/s]MovieWriter imagemagick unavailable; using Pillow instead.
# /tmp/ipykernel_3305416/548090082.py:16: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   target_voxel = torch.tensor(target.squeeze())
#  64%|██████▍   | 50/78 [00:25<00:14,  1.98it/s]MovieWriter imagemagick unavailable; using Pillow instead.
# /tmp/ipykernel_3305416/548090082.py:16: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   target_voxel = torch.tensor(target.squeeze())
#  65%|██████▌   | 51/78 [00:26<00:13,  1.97it/s]MovieWriter imagemagick unavailable; using Pillow instead.
# /tmp/ipykernel_3305416/548090082.py:16: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   target_voxel = torch.tensor(target.squeeze())
#  67%|██████▋   | 52/78 [00:26<00:12,  2.01it/s]MovieWriter imagemagick unavailable; using Pillow instead.
# /tmp/ipykernel_3305416/548090082.py:16: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   target_voxel = torch.tensor(target.squeeze())
#  68%|██████▊   | 53/78 [00:27<00:12,  2.02it/s]MovieWriter imagemagick unavailable; using Pillow instead.
# /tmp/ipykernel_3305416/548090082.py:16: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   target_voxel = torch.tensor(target.squeeze())
#  69%|██████▉   | 54/78 [00:27<00:11,  2.04it/s]MovieWriter imagemagick unavailable; using Pillow instead.
# /tmp/ipykernel_3305416/548090082.py:16: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   target_voxel = torch.tensor(target.squeeze())
#  71%|███████   | 55/78 [00:28<00:11,  2.01it/s]MovieWriter imagemagick unavailable; using Pillow instead.
# /tmp/ipykernel_3305416/548090082.py:16: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   target_voxel = torch.tensor(target.squeeze())
#  72%|███████▏  | 56/78 [00:29<00:13,  1.61it/s]MovieWriter imagemagick unavailable; using Pillow instead.
# /tmp/ipykernel_3305416/548090082.py:16: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   target_voxel = torch.tensor(target.squeeze())
#  73%|███████▎  | 57/78 [00:29<00:12,  1.70it/s]MovieWriter imagemagick unavailable; using Pillow instead.
# /tmp/ipykernel_3305416/548090082.py:16: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   target_voxel = torch.tensor(target.squeeze())
#  74%|███████▍  | 58/78 [00:30<00:11,  1.78it/s]MovieWriter imagemagick unavailable; using Pillow instead.
# /tmp/ipykernel_3305416/548090082.py:16: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   target_voxel = torch.tensor(target.squeeze())
#  76%|███████▌  | 59/78 [00:30<00:10,  1.84it/s]MovieWriter imagemagick unavailable; using Pillow instead.
# /tmp/ipykernel_3305416/548090082.py:16: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   target_voxel = torch.tensor(target.squeeze())
#  77%|███████▋  | 60/78 [00:31<00:09,  1.89it/s]MovieWriter imagemagick unavailable; using Pillow instead.
# /tmp/ipykernel_3305416/548090082.py:16: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   target_voxel = torch.tensor(target.squeeze())
#  78%|███████▊  | 61/78 [00:31<00:08,  1.91it/s]MovieWriter imagemagick unavailable; using Pillow instead.
# /tmp/ipykernel_3305416/548090082.py:16: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   target_voxel = torch.tensor(target.squeeze())
#  79%|███████▉  | 62/78 [00:32<00:08,  1.97it/s]MovieWriter imagemagick unavailable; using Pillow instead.
# /tmp/ipykernel_3305416/548090082.py:16: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   target_voxel = torch.tensor(target.squeeze())
#  81%|████████  | 63/78 [00:32<00:07,  1.94it/s]MovieWriter imagemagick unavailable; using Pillow instead.
# /tmp/ipykernel_3305416/548090082.py:16: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   target_voxel = torch.tensor(target.squeeze())
#  82%|████████▏ | 64/78 [00:33<00:06,  2.00it/s]MovieWriter imagemagick unavailable; using Pillow instead.
# /tmp/ipykernel_3305416/548090082.py:16: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   target_voxel = torch.tensor(target.squeeze())
#  83%|████████▎ | 65/78 [00:33<00:06,  2.05it/s]MovieWriter imagemagick unavailable; using Pillow instead.
# /tmp/ipykernel_3305416/548090082.py:16: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   target_voxel = torch.tensor(target.squeeze())
#  85%|████████▍ | 66/78 [00:34<00:07,  1.59it/s]MovieWriter imagemagick unavailable; using Pillow instead.
# /tmp/ipykernel_3305416/548090082.py:16: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   target_voxel = torch.tensor(target.squeeze())
#  86%|████████▌ | 67/78 [00:35<00:06,  1.73it/s]MovieWriter imagemagick unavailable; using Pillow instead.
# /tmp/ipykernel_3305416/548090082.py:16: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   target_voxel = torch.tensor(target.squeeze())
#  87%|████████▋ | 68/78 [00:35<00:05,  1.79it/s]MovieWriter imagemagick unavailable; using Pillow instead.
# /tmp/ipykernel_3305416/548090082.py:16: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   target_voxel = torch.tensor(target.squeeze())
#  88%|████████▊ | 69/78 [00:36<00:04,  1.84it/s]MovieWriter imagemagick unavailable; using Pillow instead.
# /tmp/ipykernel_3305416/548090082.py:16: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   target_voxel = torch.tensor(target.squeeze())
#  90%|████████▉ | 70/78 [00:36<00:04,  1.89it/s]MovieWriter imagemagick unavailable; using Pillow instead.
# /tmp/ipykernel_3305416/548090082.py:16: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   target_voxel = torch.tensor(target.squeeze())
#  91%|█████████ | 71/78 [00:37<00:03,  1.93it/s]MovieWriter imagemagick unavailable; using Pillow instead.
# /tmp/ipykernel_3305416/548090082.py:16: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   target_voxel = torch.tensor(target.squeeze())
#  92%|█████████▏| 72/78 [00:37<00:03,  1.99it/s]MovieWriter imagemagick unavailable; using Pillow instead.
# /tmp/ipykernel_3305416/548090082.py:16: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   target_voxel = torch.tensor(target.squeeze())
#  94%|█████████▎| 73/78 [00:38<00:02,  2.01it/s]MovieWriter imagemagick unavailable; using Pillow instead.
# /tmp/ipykernel_3305416/548090082.py:16: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   target_voxel = torch.tensor(target.squeeze())
#  95%|█████████▍| 74/78 [00:38<00:01,  2.04it/s]MovieWriter imagemagick unavailable; using Pillow instead.
# /tmp/ipykernel_3305416/548090082.py:16: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   target_voxel = torch.tensor(target.squeeze())
#  96%|█████████▌| 75/78 [00:39<00:01,  2.03it/s]MovieWriter imagemagick unavailable; using Pillow instead.
# /tmp/ipykernel_3305416/548090082.py:16: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   target_voxel = torch.tensor(target.squeeze())
#  97%|█████████▋| 76/78 [00:39<00:00,  2.02it/s]MovieWriter imagemagick unavailable; using Pillow instead.
# /tmp/ipykernel_3305416/548090082.py:16: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   target_voxel = torch.tensor(target.squeeze())
#  99%|█████████▊| 77/78 [00:40<00:00,  2.01it/s]MovieWriter imagemagick unavailable; using Pillow instead.
# /tmp/ipykernel_3305416/548090082.py:16: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   target_voxel = torch.tensor(target.squeeze())
# 100%|██████████| 78/78 [00:40<00:00,  1.92it/s]
